# %% [markdown]
# # MIT COLLABORATION PROJECT

# %% [markdown]
# ## Introduction
# Out-of-school children rate (SDG4.1.4) – Percentage of children or young people in the official age range for a given level of education who are not attending either pre-primary, primary, secondary, or higher levels of education.
#
# #### Unit of measure:	Percentage
# #### Time frame for survey
# Household survey data from the past 10 years are used for the calculation of adjusted net attendance rate. For countries with multiple years of data, the most recent dataset is used.

# %% [markdown]
# ### Glossary - the database contains the following
# **ISO**	Three-digit alphabetical codes International Standard ISO 3166-1 assigned by the International Organization for Standardization (ISO). The latest version is available online at http://www.iso.org/iso/home/standards/country_codes.htm. (column A)
# **Countries and areas:**	The UNICEF Global databases contain a set of 202 countries and Kosovo under UNSC res. 1244* as reported on through the State of the World's Children Statistical Annex 2017 (column B)
#
# **Data Source:**	Short name for data source, followed by the year(s) in which the data collection (e.g., survey interviews) took place (column P)
# **Time period:**	Represents the year(s) in which the data collection (e.g. survey interviews) took place. (column Q)
#
# **Region, Sub-region**	UNICEF regions (column C) and UNICEF Sub-regions (column D)
# EAP	East Asia and the Pacific
# ECA	Europe and Central Asia
# EECA	Eastern Europe and Central Asia
# ESA	Eastern and Southern Africa
# LAC	Latin America and the Caribbean
# MENA	Middle East and North Africa
# NA	North America
# SA	South Asia
# SSA	Sub-Saharan Africa
# WCA	West and Central Africa
# **Development regions:**	Economies are currently divided into four income groupings: low, lower-middle, upper-middle, and high. Income is measured using **gross national income (GNI) per capita, in U.S. dollars**, converted from local currency using the World Bank Atlas method (column E).
#
# **Regional Aggregations**
# Regional aggregates with less than 50% of the corresponding school-aged population coverage have been suppressed
#
# * All references to Kosovo in this dataset should be understood to be in the context of United Nations Security Council resolution 1244 (1999).

# %%
# Importing Necessary Libraries for project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib import style
import seaborn as sns

# %% [markdown]
# # Lower-Secondary Level

# %%
# reading the data set
Lower_Sec_level = pd.read_csv("Lower secondary_level1.csv", encoding='ISO-8859-1')
Lower_Sec_level.head()
# Out:
#   ISO3      Country Region  Sub-Region LS_Development Region   LS_Total  \
# 0  AFG  Afghanistan      SA         SA        Least Developed      40.0
# 1  ALB      Albania     ECA       EECA         More Developed       2.0
# 2  DZA      Algeria    MENA       MENA         Less Developed       4.0
# 3  AND      Andorra     ECA         WE         More Developed       NaN
# 4  AGO       Angola     SSA        ESA        Least Developed      15.0
#
#    Female_LS  Male_lS  LS_residence_Rural  LS_residence_Uraban   \
# 0       56.0     25.0                46.0                  23.0
# 1        2.0      2.0                 2.0                   2.0
# 2        4.0      4.0                 6.0                   3.0
# 3        NaN      NaN                 NaN                   NaN
# 4       17.0     14.0                28.0                  10.0
#
#    LS_Wealth_Porrest  LS_wealth_Second  LS_wealth_Middle  LS_wealth_Fourth  \
# 0               50.0              48.0              49.0              33.0
# 1                4.0               2.0               2.0               1.0
# 2                9.0               4.0               3.0               2.0
# 3                NaN               NaN               NaN               NaN
# 4               31.0              26.0              16.0               6.0
#
#    LS_wealth_Richest LS_Data_Source  LS_Time_Period
# 0               21.0       DHS 2015          2015.0
# 1                1.0    DHS 2017-18          2018.0
# 2                1.0      MICS 2019          2020.0
# 3                NaN            NaN             NaN
# 4                4.0    DHS 2015-16          2016.0

# %%
Lower_Sec_level.dtypes
# Out:
# ISO3                       object
# Country                    object
# Region                     object
# Sub-Region                 object
# LS_Development Region      object
# LS_Total                  float64
# Female_LS                 float64
# Male_lS                   float64
# LS_residence_Rural        float64
# LS_residence_Uraban       float64
# LS_Wealth_Porrest         float64
# LS_wealth_Second          float64
# LS_wealth_Middle          float64
# LS_wealth_Fourth          float64
# LS_wealth_Richest         float64
# LS_Data_Source             object
# LS_Time_Period            float64
# dtype: object

# %%
#checking for null/missing values
Lower_Sec_level.isnull().any().any()
# Out:
# True

# %%
Lower_Sec_level.isnull().any()
# Out:
# ISO3                      False
# Country                   False
# Region                     True
# Sub-Region                 True
# LS_Development Region      True
# LS_Total                   True
# Female_LS                  True
# Male_lS                    True
# LS_residence_Rural         True
# LS_residence_Uraban        True
# LS_Wealth_Porrest          True
# LS_wealth_Second           True
# LS_wealth_Middle           True
# LS_wealth_Fourth           True
# LS_wealth_Richest          True
# LS_Data_Source             True
# LS_Time_Period             True
# dtype: bool

# %%
Lower_Sec_level.isnull().sum()
# Out:
# ISO3                       0
# Country                    0
# Region                     2
# Sub-Region                 3
# LS_Development Region      1
# LS_Total                  87
# Female_LS                 87
# Male_lS                   87
# LS_residence_Rural        90
# LS_residence_Uraban       90
# LS_Wealth_Porrest         96
# LS_wealth_Second          96
# LS_wealth_Middle          96
# LS_wealth_Fourth          96
# LS_wealth_Richest         96
# LS_Data_Source            87
# LS_Time_Period            87
# dtype: int64

# %%
Lower_Sec_level.isnull().sum() / (len(Lower_Sec_level))*100
# Out:
# ISO3                       0.000000
# Country                    0.000000
# Region                     0.985222
# Sub-Region                 1.477833
# LS_Development Region      0.492611
# LS_Total                  42.857143
# Female_LS                 42.857143
# Male_lS                   42.857143
# LS_residence_Rural        44.334975
# LS_residence_Uraban       44.334975
# LS_Wealth_Porrest         47.290640
# LS_wealth_Second          47.290640
# LS_wealth_Middle          47.290640
# LS_wealth_Fourth          47.290640
# LS_wealth_Richest         47.290640
# LS_Data_Source            42.857143
# LS_Time_Period            42.857143
# dtype: float64

# %%
Lower_Sec_level_clean = Lower_Sec_level.copy()

# %%
Lower_Sec_level.columns
# Out:
# Index(['ISO3', 'Country', 'Region ', 'Sub-Region', 'LS_Development Region ',
#        'LS_Total', 'Female_LS', 'Male_lS', 'LS_residence_Rural',
#        'LS_residence_Uraban ', 'LS_Wealth_Porrest', 'LS_wealth_Second',
#        'LS_wealth_Middle', 'LS_wealth_Fourth', 'LS_wealth_Richest',
#        'LS_Data_Source', 'LS_Time_Period'],
#       dtype='object')

# %%
Lower_Sec_level["LS_Development Region "].unique()
# Out:
# array(['Least Developed', 'More Developed', 'Less Developed',
#        'Not Classified', nan], dtype=object)

# %%
developing_countries = Lower_Sec_level[Lower_Sec_level['LS_Development Region '].isin(['Least Developed', 'Less Developed'])]

# %%
len(developing_countries)
# Out:
# 146

# %%
developing_countries1=  Lower_Sec_level[Lower_Sec_level['LS_Development Region '] == 'Least Developed']

# %%
len(developing_countries1)
# Out:
# 47

# %%
developing_countries1.isnull().any()
# Out:
# ISO3                      False
# Country                   False
# Region                    False
# Sub-Region                False
# LS_Development Region     False
# LS_Total                   True
# Female_LS                  True
# Male_lS                    True
# LS_residence_Rural         True
# LS_residence_Uraban        True
# LS_Wealth_Porrest          True
# LS_wealth_Second           True
# LS_wealth_Middle           True
# LS_wealth_Fourth           True
# LS_wealth_Richest          True
# LS_Data_Source             True
# LS_Time_Period             True
# dtype: bool

# %%
developing_countries1.isnull().sum()
# Out:
# ISO3                      0
# Country                   0
# Region                    0
# Sub-Region                0
# LS_Development Region     0
# LS_Total                  5
# Female_LS                 5
# Male_lS                   5
# LS_residence_Rural        5
# LS_residence_Uraban       5
# LS_Wealth_Porrest         5
# LS_wealth_Second          5
# LS_wealth_Middle          5
# LS_wealth_Fourth          5
# LS_wealth_Richest         5
# LS_Data_Source            5
# LS_Time_Period            5
# dtype: int64

# %%
developing_countries1["Country"].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Bangladesh', 'Benin', 'Bhutan',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Central African Republic',
#        'Chad', 'Comoros', 'Democratic Republic of the Congo', 'Djibouti',
#        'Eritrea', 'Ethiopia', 'Gambia', 'Guinea', 'Guinea-Bissau',
#        'Haiti', 'Kiribati', "Lao People's Democratic Republic", 'Lesotho',
#        'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania',
#        'Mozambique', 'Myanmar', 'Nepal', 'Niger', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Sierra Leone',
#        'Solomon Islands', 'Somalia', 'South Sudan', 'Sudan',
#        'Timor-Leste', 'Togo', 'Tuvalu', 'Uganda',
#        'United Republic of Tanzania', 'Vanuatu', 'Yemen', 'Zambia'],
#       dtype=object)

# %%
developing_countries.isnull().sum()
# Out:
# ISO3                       0
# Country                    0
# Region                     0
# Sub-Region                 0
# LS_Development Region      0
# LS_Total                  41
# Female_LS                 41
# Male_lS                   41
# LS_residence_Rural        43
# LS_residence_Uraban       43
# LS_Wealth_Porrest         49
# LS_wealth_Second          49
# LS_wealth_Middle          49
# LS_wealth_Fourth          49
# LS_wealth_Richest         49
# LS_Data_Source            41
# LS_Time_Period            41
# dtype: int64

# %%
developing_countries["Country"].unique()
# Out:
# array(['Afghanistan', 'Algeria', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Burkina Faso', 'Burundi', 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Cuba', "Côte d'Ivoire",
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Fiji',
#        'Gabon', 'Gambia', 'Georgia', 'Ghana', 'Grenada', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'India',
#        'Indonesia', 'Iran (Islamic Republic of)', 'Iraq', 'Jamaica',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kuwait',
#        'Kyrgyzstan', "Lao People's Democratic Republic", 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Marshall Islands', 'Mauritania', 'Mauritius',
#        'Mexico', 'Micronesia (Federated States of)', 'Mongolia',
#        'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Oman', 'Pakistan',
#        'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Qatar', 'Republic of Korea', 'Rwanda',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Seychelles',
#        'Sierra Leone', 'Singapore', 'Solomon Islands', 'Somalia',
#        'South Africa', 'South Sudan', 'Sri Lanka', 'State of Palestine',
#        'Sudan', 'Suriname', 'Syrian Arab Republic', 'Tajikistan',
#        'Thailand', 'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago',
#        'Tunisia', 'Turkey', 'Turkmenistan', 'Tuvalu', 'Uganda',
#        'United Arab Emirates', 'United Republic of Tanzania', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
# Assuming 'prim_level' is your DataFrame
rows_with_missing_values = developing_countries1[developing_countries1.isnull().any(axis=1)]

# Display the rows with missing values
rows_with_missing_values
# Out:
#     ISO3          Country Region  Sub-Region LS_Development Region   LS_Total  \
# 51   DJI         Djibouti     SSA        ESA        Least Developed       NaN
# 58   ERI          Eritrea     SSA        ESA        Least Developed       NaN
# 165  SLB  Solomon Islands     EAP        EAP        Least Developed       NaN
# 166  SOM          Somalia     SSA        ESA        Least Developed       NaN
# 197  VUT          Vanuatu     EAP        EAP        Least Developed       NaN
#
#      Female_LS  Male_lS  LS_residence_Rural  LS_residence_Uraban   \
# 51         NaN      NaN                 NaN                   NaN
# 58         NaN      NaN                 NaN                   NaN
# 165        NaN      NaN                 NaN                   NaN
# 166        NaN      NaN                 NaN                   NaN
# 197        NaN      NaN                 NaN                   NaN
#
#      LS_Wealth_Porrest  LS_wealth_Second  LS_wealth_Middle  LS_wealth_Fourth  \
# 51                 NaN               NaN               NaN               NaN
# 58                 NaN               NaN               NaN               NaN
# 165                NaN               NaN               NaN               NaN
# 166                NaN               NaN               NaN               NaN
# 197                NaN               NaN               NaN               NaN
#
#      LS_wealth_Richest LS_Data_Source  LS_Time_Period
# 51                 NaN            NaN             NaN
# 58                 NaN            NaN             NaN
# 165                NaN            NaN             NaN
# 166                NaN            NaN             NaN
# 197                NaN            NaN             NaN

# %%
developing_countries_without_na = developing_countries1.dropna()

# %%
developing_countries_without_na.isnull().any().any()
# Out:
# False

# %%
developing_countries_without_na["Country"].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Bangladesh', 'Benin', 'Bhutan',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Central African Republic',
#        'Chad', 'Comoros', 'Democratic Republic of the Congo', 'Ethiopia',
#        'Gambia', 'Guinea', 'Guinea-Bissau', 'Haiti', 'Kiribati',
#        "Lao People's Democratic Republic", 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mozambique',
#        'Myanmar', 'Nepal', 'Niger', 'Rwanda', 'Sao Tome and Principe',
#        'Senegal', 'Sierra Leone', 'South Sudan', 'Sudan', 'Timor-Leste',
#        'Togo', 'Tuvalu', 'Uganda', 'United Republic of Tanzania', 'Yemen',
#        'Zambia'], dtype=object)

# %%
developing_countries_without_na_reset = developing_countries_without_na.reset_index(drop=True)

# %%
developing_countries_without_na_reset
# Out:
#    ISO3                           Country Region  Sub-Region  \
# 0   AFG                       Afghanistan      SA         SA
# 1   AGO                            Angola     SSA        ESA
# 2   BGD                        Bangladesh      SA         SA
# 3   BEN                             Benin     SSA        WCA
# 4   BTN                            Bhutan      SA         SA
# 5   BFA                      Burkina Faso     SSA        WCA
# 6   BDI                           Burundi     SSA        ESA
# 7   KHM                          Cambodia     EAP        EAP
# 8   CAF          Central African Republic     SSA        WCA
# 9   TCD                              Chad     SSA        WCA
# 10  COM                           Comoros     SSA        ESA
# 11  COD  Democratic Republic of the Congo     SSA        WCA
# 12  ETH                          Ethiopia     SSA        ESA
# 13  GMB                            Gambia     SSA        WCA
# 14  GIN                            Guinea     SSA        WCA
# 15  GNB                     Guinea-Bissau     SSA        WCA
# 16  HTI                             Haiti     LAC        LAC
# 17  KIR                          Kiribati     EAP        EAP
# 18  LAO  Lao People's Democratic Republic     EAP        EAP
# 19  LSO                           Lesotho     SSA        ESA
# 20  LBR                           Liberia     SSA        WCA
# 21  MDG                        Madagascar     SSA        ESA
# 22  MWI                            Malawi     SSA        ESA
# 23  MLI                              Mali     SSA        WCA
# 24  MRT                        Mauritania     SSA        WCA
# 25  MOZ                        Mozambique     SSA        ESA
# 26  MMR                           Myanmar     EAP        EAP
# 27  NPL                             Nepal      SA         SA
# 28  NER                             Niger     SSA        WCA
# 29  RWA                            Rwanda     SSA        ESA
# 30  STP             Sao Tome and Principe     SSA        WCA
# 31  SEN                           Senegal     SSA        WCA
# 32  SLE                      Sierra Leone     SSA        WCA
# 33  SSD                       South Sudan     SSA        ESA
# 34  SDN                             Sudan     SSA        ESA
# 35  TLS                       Timor-Leste     EAP        EAP
# 36  TGO                              Togo     SSA        WCA
# 37  TUV                            Tuvalu     EAP        EAP
# 38  UGA                            Uganda     SSA        ESA
# 39  TZA       United Republic of Tanzania     SSA        ESA
# 40  YEM                             Yemen    MENA       MENA
# 41  ZMB                            Zambia     SSA        ESA
#
#    LS_Development Region   LS_Total  Female_LS  Male_lS  LS_residence_Rural  \
# 0         Least Developed      40.0       56.0     25.0                46.0
# 1         Least Developed      15.0       17.0     14.0                28.0
# 2         Least Developed      13.0        8.0     18.0                13.0
# 3         Least Developed      41.0       47.0     36.0                48.0
# 4         Least Developed      19.0       18.0     20.0                23.0
# 5         Least Developed      57.0       59.0     56.0                65.0
# 6         Least Developed      29.0       28.0     31.0                31.0
# 7         Least Developed      25.0       25.0     26.0                26.0
# 8         Least Developed      24.0       30.0     18.0                33.0
# 9         Least Developed      53.0       58.0     47.0                57.0
# 10        Least Developed      14.0       14.0     15.0                16.0
# 11        Least Developed      17.0       18.0     16.0                21.0
# 12        Least Developed      31.0       31.0     30.0                33.0
# 13        Least Developed      33.0       35.0     30.0                45.0
# 14        Least Developed      46.0       54.0     38.0                62.0
# 15        Least Developed      23.0       26.0     20.0                27.0
# 16        Least Developed       6.0        5.0      7.0                 8.0
# 17        Least Developed      10.0        5.0     15.0                11.0
# 18        Least Developed      20.0       22.0     18.0                22.0
# 19        Least Developed      14.0        9.0     19.0                18.0
# 20        Least Developed      20.0       18.0     21.0                29.0
# 21        Least Developed      36.0       33.0     38.0                40.0
# 22        Least Developed       8.0        8.0      8.0                 8.0
# 23        Least Developed      59.0       63.0     55.0                68.0
# 24        Least Developed      41.0       42.0     40.0                52.0
# 25        Least Developed      33.0       38.0     28.0                41.0
# 26        Least Developed      17.0       17.0     16.0                19.0
# 27        Least Developed       4.0        4.0      4.0                 5.0
# 28        Least Developed      70.0       73.0     67.0                79.0
# 29        Least Developed      26.0       26.0     26.0                26.0
# 30        Least Developed       6.0        4.0      9.0                 5.0
# 31        Least Developed      39.0       36.0     42.0                50.0
# 32        Least Developed      19.0       18.0     20.0                29.0
# 33        Least Developed      63.0       67.0     59.0                69.0
# 34        Least Developed      21.0       25.0     16.0                26.0
# 35        Least Developed       9.0        8.0     10.0                10.0
# 36        Least Developed      12.0       14.0     10.0                14.0
# 37        Least Developed      23.0       17.0     26.0                31.0
# 38        Least Developed      23.0       23.0     22.0                23.0
# 39        Least Developed      57.0       58.0     56.0                62.0
# 40        Least Developed      22.0       32.0     12.0                27.0
# 41        Least Developed      23.0       27.0     20.0                29.0
#
#     LS_residence_Uraban   LS_Wealth_Porrest  LS_wealth_Second  \
# 0                   23.0               50.0              48.0
# 1                   10.0               31.0              26.0
# 2                   12.0               19.0              15.0
# 3                   31.0               65.0              52.0
# 4                   10.0               35.0              25.0
# 5                   31.0               77.0              67.0
# 6                   20.0               49.0              35.0
# 7                   20.0               40.0              29.0
# 8                   11.0               40.0              35.0
# 9                   33.0               77.0              70.0
# 10                  11.0               27.0              16.0
# 11                  12.0               28.0              17.0
# 12                  22.0               48.0              40.0
# 13                  23.0               43.0              42.0
# 14                  26.0               72.0              59.0
# 15                  18.0               28.0              26.0
# 16                   3.0               14.0               7.0
# 17                   9.0               16.0              11.0
# 18                  15.0               32.0              20.0
# 19                   7.0               23.0              20.0
# 20                  14.0               38.0              24.0
# 21                  21.0               61.0              47.0
# 22                   5.0               14.0               9.0
# 23                  32.0               83.0              77.0
# 24                  28.0               62.0              51.0
# 25                  19.0               50.0              49.0
# 26                  10.0               30.0              18.0
# 27                   4.0                6.0               7.0
# 28                  37.0               90.0              80.0
# 29                  24.0               34.0              29.0
# 30                   8.0               16.0               6.0
# 31                  25.0               57.0              47.0
# 32                   8.0               39.0              29.0
# 33                  44.0               85.0              74.0
# 34                   8.0               33.0              31.0
# 35                   5.0               16.0              11.0
# 36                  10.0               20.0              14.0
# 37                  19.0               29.0              16.0
# 38                  24.0               29.0              22.0
# 39                  46.0               77.0              67.0
# 40                   8.0               45.0              27.0
# 41                  14.0               42.0              32.0
#
#     LS_wealth_Middle  LS_wealth_Fourth  LS_wealth_Richest LS_Data_Source  \
# 0               49.0              33.0               21.0       DHS 2015
# 1               16.0               6.0                4.0    DHS 2015-16
# 2               11.0              11.0                7.0      MICS 2019
# 3               42.0              31.0               18.0    DHS 2017-18
# 4               18.0              10.0               11.0      MICS 2010
# 5               62.0              49.0               32.0       DHS 2010
# 6               26.0              20.0               22.0    DHS 2016-17
# 7               24.0              17.0               15.0       DHS 2014
# 8               28.0              16.0                9.0   MICS 2018-19
# 9               57.0              36.0               27.0      MICS 2019
# 10              13.0               9.0                8.0       DHS 2012
# 11              17.0              16.0                8.0   MICS 2017-18
# 12              28.0              24.0               20.0       DHS 2016
# 13              44.0              24.0               12.0       DHS 2013
# 14              57.0              39.0               20.0       DHS 2018
# 15              27.0              20.0               16.0   MICS 2018-19
# 16               3.0               3.0                3.0    DHS 2016-17
# 17              11.0               9.0                3.0   MICS 2018-19
# 18              18.0              12.0               13.0      MICS 2017
# 19              13.0               6.0                5.0      MICS 2018
# 20              21.0              15.0                9.0       DHS 2013
# 21              32.0              24.0               12.0      MICS 2018
# 22               8.0               6.0                4.0    DHS 2015-16
# 23              67.0              51.0               29.0      MICS 2015
# 24              40.0              31.0               17.0      MICS 2015
# 25              38.0              27.0               13.0       DHS 2011
# 26              15.0               9.0                6.0    DHS 2015-16
# 27               4.0               2.0                1.0      MICS 2019
# 28              80.0              72.0               41.0       DHS 2012
# 29              24.0              21.0               24.0    DHS 2014-15
# 30               5.0               3.0                2.0      MICS 2019
# 31              39.0              34.0               17.0       DHS 2019
# 32              17.0              10.0                7.0      MICS 2017
# 33              67.0              55.0               34.0      MICS 2010
# 34              22.0              11.0                3.0      MICS 2014
# 35               8.0               5.0                3.0       DHS 2016
# 36               9.0               7.0               10.0      MICS 2017
# 37              18.0              26.0               26.0   MICS 2019-20
# 38              21.0              19.0               25.0       DHS 2016
# 39              61.0              44.0               44.0    DHS 2015-16
# 40              19.0              12.0                4.0       DHS 2013
# 41              23.0              17.0                9.0       DHS 2018
#
#     LS_Time_Period
# 0           2015.0
# 1           2016.0
# 2           2019.0
# 3           2018.0
# 4           2010.0
# 5           2010.0
# 6           2017.0
# 7           2014.0
# 8           2019.0
# 9           2019.0
# 10          2012.0
# 11          2018.0
# 12          2016.0
# 13          2013.0
# 14          2018.0
# 15          2019.0
# 16          2017.0
# 17          2019.0
# 18          2017.0
# 19          2018.0
# 20          2013.0
# 21          2018.0
# 22          2016.0
# 23          2015.0
# 24          2015.0
# 25          2011.0
# 26          2016.0
# 27          2019.0
# 28          2012.0
# 29          2015.0
# 30          2019.0
# 31          2019.0
# 32          2017.0
# 33          2010.0
# 34          2014.0
# 35          2016.0
# 36          2017.0
# 37          2020.0
# 38          2016.0
# 39          2016.0
# 40          2013.0
# 41          2018.0

# %%
developing_countries_without_na_reset.to_csv('LowerSecodndaryCleanedDevelopingCountriesOnly.csv')

# %% [markdown]
# ## Primary_Level

# %%
# reading the data set
prim_level = pd.read_csv("Primary level.csv", encoding='ISO-8859-1')
prim_level.head()
# Out:
#   ISO3      Country Region  Sub-Region P_Development Region   P_Total  \
# 0  AFG  Afghanistan      SA         SA       Least Developed     37.0
# 1  ALB      Albania     ECA       EECA        More Developed      2.0
# 2  DZA      Algeria    MENA       MENA        Less Developed      2.0
# 3  AND      Andorra     ECA         WE        More Developed      NaN
# 4  AGO       Angola     SSA        ESA       Least Developed     22.0
#
#    Femal_P  Male_P  P_residence_Rural  P_residence_Uraban   P_Wealth_Porrest  \
# 0     47.0    28.0               42.0                 19.0              42.0
# 1      2.0     3.0                4.0                  1.0               4.0
# 2      2.0     2.0                2.0                  1.0               4.0
# 3      NaN     NaN                NaN                  NaN               NaN
# 4     22.0    21.0               35.0                 14.0              39.0
#
#    P_wealth_Second  P_wealth_Middle  P_wealth_Fourth  P_wealth_Richest  \
# 0             47.0             46.0             32.0              16.0
# 1              3.0              2.0              2.0               1.0
# 2              1.0              2.0              1.0               1.0
# 3              NaN              NaN              NaN               NaN
# 4             33.0             19.0             12.0               5.0
#
#   P_Data_Source  P_Time_Period
# 0      DHS 2015         2015.0
# 1   DHS 2017-18         2018.0
# 2     MICS 2019         2020.0
# 3           NaN            NaN
# 4   DHS 2015-16         2016.0

# %%
prim_level.dtypes
# Out:
# ISO3                      object
# Country                   object
# Region                    object
# Sub-Region                object
# P_Development Region      object
# P_Total                  float64
# Femal_P                  float64
# Male_P                   float64
# P_residence_Rural        float64
# P_residence_Uraban       float64
# P_Wealth_Porrest         float64
# P_wealth_Second          float64
# P_wealth_Middle          float64
# P_wealth_Fourth          float64
# P_wealth_Richest         float64
# P_Data_Source             object
# P_Time_Period            float64
# dtype: object

# %%
prim_level.isnull().any().any()
# Out:
# True

# %%
prim_level.isnull().any()
# Out:
# ISO3                     False
# Country                  False
# Region                    True
# Sub-Region                True
# P_Development Region      True
# P_Total                   True
# Femal_P                   True
# Male_P                    True
# P_residence_Rural         True
# P_residence_Uraban        True
# P_Wealth_Porrest          True
# P_wealth_Second           True
# P_wealth_Middle           True
# P_wealth_Fourth           True
# P_wealth_Richest          True
# P_Data_Source             True
# P_Time_Period             True
# dtype: bool

# %%
prim_level.isnull().sum()
# Out:
# ISO3                      0
# Country                   0
# Region                    2
# Sub-Region                3
# P_Development Region      1
# P_Total                  85
# Femal_P                  85
# Male_P                   85
# P_residence_Rural        89
# P_residence_Uraban       89
# P_Wealth_Porrest         95
# P_wealth_Second          95
# P_wealth_Middle          95
# P_wealth_Fourth          95
# P_wealth_Richest         95
# P_Data_Source            85
# P_Time_Period            85
# dtype: int64

# %%
prim_level.isnull().sum() / (len(prim_level))*100
# Out:
# ISO3                      0.000000
# Country                   0.000000
# Region                    0.985222
# Sub-Region                1.477833
# P_Development Region      0.492611
# P_Total                  41.871921
# Femal_P                  41.871921
# Male_P                   41.871921
# P_residence_Rural        43.842365
# P_residence_Uraban       43.842365
# P_Wealth_Porrest         46.798030
# P_wealth_Second          46.798030
# P_wealth_Middle          46.798030
# P_wealth_Fourth          46.798030
# P_wealth_Richest         46.798030
# P_Data_Source            41.871921
# P_Time_Period            41.871921
# dtype: float64

# %%
developing_countriesP= prim_level[prim_level['P_Development Region '] == 'Least Developed']

# %%
developing_countriesP.isnull().any().any()
# Out:
# True

# %%
developing_countriesP.isnull().sum()
# Out:
# ISO3                     0
# Country                  0
# Region                   0
# Sub-Region               0
# P_Development Region     0
# P_Total                  5
# Femal_P                  5
# Male_P                   5
# P_residence_Rural        5
# P_residence_Uraban       5
# P_Wealth_Porrest         5
# P_wealth_Second          5
# P_wealth_Middle          5
# P_wealth_Fourth          5
# P_wealth_Richest         5
# P_Data_Source            5
# P_Time_Period            5
# dtype: int64

# %%
rows_with_missing_valuesP = developing_countriesP[developing_countriesP.isnull().any(axis=1)]

# Display the rows with missing values
rows_with_missing_valuesP
# Out:
#     ISO3          Country Region  Sub-Region P_Development Region   P_Total  \
# 51   DJI         Djibouti     SSA        ESA       Least Developed      NaN
# 58   ERI          Eritrea     SSA        ESA       Least Developed      NaN
# 165  SLB  Solomon Islands     EAP        EAP       Least Developed      NaN
# 166  SOM          Somalia     SSA        ESA       Least Developed      NaN
# 197  VUT          Vanuatu     EAP        EAP       Least Developed      NaN
#
#      Femal_P  Male_P  P_residence_Rural  P_residence_Uraban   \
# 51       NaN     NaN                NaN                  NaN
# 58       NaN     NaN                NaN                  NaN
# 165      NaN     NaN                NaN                  NaN
# 166      NaN     NaN                NaN                  NaN
# 197      NaN     NaN                NaN                  NaN
#
#      P_Wealth_Porrest  P_wealth_Second  P_wealth_Middle  P_wealth_Fourth  \
# 51                NaN              NaN              NaN              NaN
# 58                NaN              NaN              NaN              NaN
# 165               NaN              NaN              NaN              NaN
# 166               NaN              NaN              NaN              NaN
# 197               NaN              NaN              NaN              NaN
#
#      P_wealth_Richest P_Data_Source  P_Time_Period
# 51                NaN           NaN            NaN
# 58                NaN           NaN            NaN
# 165               NaN           NaN            NaN
# 166               NaN           NaN            NaN
# 197               NaN           NaN            NaN

# %%
developing_countriesP_without_na = developing_countriesP.dropna()

# %%
developing_countriesP_without_na.isnull().any().any()
# Out:
# False

# %%
developing_countriesP_without_na.head()
# Out:
#    ISO3      Country Region  Sub-Region P_Development Region   P_Total  \
# 0   AFG  Afghanistan      SA         SA       Least Developed     37.0
# 4   AGO       Angola     SSA        ESA       Least Developed     22.0
# 14  BGD   Bangladesh      SA         SA       Least Developed      6.0
# 19  BEN        Benin     SSA        WCA       Least Developed     32.0
# 20  BTN       Bhutan      SA         SA       Least Developed      8.0
#
#     Femal_P  Male_P  P_residence_Rural  P_residence_Uraban   P_Wealth_Porrest  \
# 0      47.0    28.0               42.0                 19.0              42.0
# 4      22.0    21.0               35.0                 14.0              39.0
# 14      5.0     8.0                6.0                  6.0               9.0
# 19     35.0    28.0               38.0                 21.0              59.0
# 20      7.0     9.0               10.0                  3.0              15.0
#
#     P_wealth_Second  P_wealth_Middle  P_wealth_Fourth  P_wealth_Richest  \
# 0              47.0             46.0             32.0              16.0
# 4              33.0             19.0             12.0               5.0
# 14              7.0              5.0              6.0               4.0
# 19             39.0             30.0             15.0               7.0
# 20             11.0              6.0              4.0               3.0
#
#    P_Data_Source  P_Time_Period
# 0       DHS 2015         2015.0
# 4    DHS 2015-16         2016.0
# 14     MICS 2019         2019.0
# 19   DHS 2017-18         2018.0
# 20     MICS 2010         2010.0

# %%
developing_countriesP_without_na_reset = developing_countriesP_without_na.reset_index(drop=True)

# %%
developing_countriesP_without_na_reset.head()
# Out:
#   ISO3      Country Region  Sub-Region P_Development Region   P_Total  \
# 0  AFG  Afghanistan      SA         SA       Least Developed     37.0
# 1  AGO       Angola     SSA        ESA       Least Developed     22.0
# 2  BGD   Bangladesh      SA         SA       Least Developed      6.0
# 3  BEN        Benin     SSA        WCA       Least Developed     32.0
# 4  BTN       Bhutan      SA         SA       Least Developed      8.0
#
#    Femal_P  Male_P  P_residence_Rural  P_residence_Uraban   P_Wealth_Porrest  \
# 0     47.0    28.0               42.0                 19.0              42.0
# 1     22.0    21.0               35.0                 14.0              39.0
# 2      5.0     8.0                6.0                  6.0               9.0
# 3     35.0    28.0               38.0                 21.0              59.0
# 4      7.0     9.0               10.0                  3.0              15.0
#
#    P_wealth_Second  P_wealth_Middle  P_wealth_Fourth  P_wealth_Richest  \
# 0             47.0             46.0             32.0              16.0
# 1             33.0             19.0             12.0               5.0
# 2              7.0              5.0              6.0               4.0
# 3             39.0             30.0             15.0               7.0
# 4             11.0              6.0              4.0               3.0
#
#   P_Data_Source  P_Time_Period
# 0      DHS 2015         2015.0
# 1   DHS 2015-16         2016.0
# 2     MICS 2019         2019.0
# 3   DHS 2017-18         2018.0
# 4     MICS 2010         2010.0

# %%
developing_countriesP_without_na_reset.to_csv('PrimaryCleanedDevelopingCountriesOnly.csv')

# %% [markdown]
# # Upper Secondary Level

# %%
# reading the data set
UpSec_level = pd.read_csv("Upper secondary_level.csv", encoding='ISO-8859-1')
UpSec_level.head()
# Out:
#   ISO3      Country Region  Sub-Region US_Development Region   US_Total  \
# 0  AFG  Afghanistan      SA         SA        Least Developed      58.0
# 1  ALB      Albania     ECA       EECA         More Developed      12.0
# 2  DZA      Algeria    MENA       MENA         Less Developed      23.0
# 3  AND      Andorra     ECA         WE         More Developed       NaN
# 4  AGO       Angola     SSA        ESA        Least Developed      29.0
#
#    Female_US  Male_US  USresidence_Rural  USresidence_Uraban   \
# 0       73.0     43.0               63.0                 45.0
# 1       12.0     12.0               16.0                  9.0
# 2       18.0     27.0               27.0                 20.0
# 3        NaN      NaN                NaN                  NaN
# 4       35.0     21.0               53.0                 19.0
#
#    US_Wealth_Porrest  US_wealth_second  US_wealth_Middle  US_wealth_Fourth  \
# 0               70.0              64.0              64.0              54.0
# 1               27.0              11.0              11.0               5.0
# 2               38.0              27.0              22.0              17.0
# 3                NaN               NaN               NaN               NaN
# 4               58.0              50.0              27.0              17.0
#
#    US_wealth_Richest US_Data_Source  US_Time_Period
# 0               40.0       DHS 2015          2015.0
# 1                5.0    DHS 2017-18          2018.0
# 2               10.0      MICS 2019          2020.0
# 3                NaN            NaN             NaN
# 4                9.0    DHS 2015-16          2016.0

# %%
UpSec_level.shape
# Out:
# (203, 17)

# %%
UpSec_level.dtypes
# Out:
# ISO3                       object
# Country                    object
# Region                     object
# Sub-Region                 object
# US_Development Region      object
# US_Total                  float64
# Female_US                 float64
# Male_US                   float64
# USresidence_Rural         float64
# USresidence_Uraban        float64
# US_Wealth_Porrest         float64
# US_wealth_second          float64
# US_wealth_Middle          float64
# US_wealth_Fourth          float64
# US_wealth_Richest         float64
# US_Data_Source             object
# US_Time_Period            float64
# dtype: object

# %%
UpSec_level.isnull().any().any()
# Out:
# True

# %%
UpSec_level.isnull().sum()
# Out:
# ISO3                       0
# Country                    0
# Region                     2
# Sub-Region                 3
# US_Development Region      1
# US_Total                  89
# Female_US                 89
# Male_US                   89
# USresidence_Rural         91
# USresidence_Uraban        91
# US_Wealth_Porrest         97
# US_wealth_second          97
# US_wealth_Middle          97
# US_wealth_Fourth          97
# US_wealth_Richest         97
# US_Data_Source            89
# US_Time_Period            89
# dtype: int64

# %%
UpSec_level["US_Development Region "].unique()
# Out:
# array(['Least Developed', 'More Developed', 'Less Developed',
#        'Not Classified', nan], dtype=object)

# %%
UpSec_level.isnull().sum() / (len(prim_level))*100
# Out:
# ISO3                       0.000000
# Country                    0.000000
# Region                     0.985222
# Sub-Region                 1.477833
# US_Development Region      0.492611
# US_Total                  43.842365
# Female_US                 43.842365
# Male_US                   43.842365
# USresidence_Rural         44.827586
# USresidence_Uraban        44.827586
# US_Wealth_Porrest         47.783251
# US_wealth_second          47.783251
# US_wealth_Middle          47.783251
# US_wealth_Fourth          47.783251
# US_wealth_Richest         47.783251
# US_Data_Source            43.842365
# US_Time_Period            43.842365
# dtype: float64

# %%
developing_countriesUpSec= UpSec_level[UpSec_level['US_Development Region '] == 'Least Developed']

# %%
developing_countriesUpSec["Country"].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Bangladesh', 'Benin', 'Bhutan',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Central African Republic',
#        'Chad', 'Comoros', 'Democratic Republic of the Congo', 'Djibouti',
#        'Eritrea', 'Ethiopia', 'Gambia', 'Guinea', 'Guinea-Bissau',
#        'Haiti', 'Kiribati', "Lao People's Democratic Republic", 'Lesotho',
#        'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania',
#        'Mozambique', 'Myanmar', 'Nepal', 'Niger', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Sierra Leone',
#        'Solomon Islands', 'Somalia', 'South Sudan', 'Sudan',
#        'Timor-Leste', 'Togo', 'Tuvalu', 'Uganda',
#        'United Republic of Tanzania', 'Vanuatu', 'Yemen', 'Zambia'],
#       dtype=object)

# %%
developing_countriesUpSec.shape
# Out:
# (47, 17)

# %%
developing_countriesUpSec.isnull().any().any()
# Out:
# True

# %%
developing_countriesUpSec.isnull().sum()
# Out:
# ISO3                      0
# Country                   0
# Region                    0
# Sub-Region                0
# US_Development Region     0
# US_Total                  5
# Female_US                 5
# Male_US                   5
# USresidence_Rural         5
# USresidence_Uraban        5
# US_Wealth_Porrest         5
# US_wealth_second          5
# US_wealth_Middle          5
# US_wealth_Fourth          5
# US_wealth_Richest         5
# US_Data_Source            5
# US_Time_Period            5
# dtype: int64

# %%
rows_with_missing_valuesUpSex = developing_countriesUpSec[developing_countriesUpSec.isnull().any(axis=1)]

# Display the rows with missing values
rows_with_missing_valuesUpSex
# Out:
#     ISO3          Country Region  Sub-Region US_Development Region   US_Total  \
# 51   DJI         Djibouti     SSA        ESA        Least Developed       NaN
# 58   ERI          Eritrea     SSA        ESA        Least Developed       NaN
# 165  SLB  Solomon Islands     EAP        EAP        Least Developed       NaN
# 166  SOM          Somalia     SSA        ESA        Least Developed       NaN
# 197  VUT          Vanuatu     EAP        EAP        Least Developed       NaN
#
#      Female_US  Male_US  USresidence_Rural  USresidence_Uraban   \
# 51         NaN      NaN                NaN                  NaN
# 58         NaN      NaN                NaN                  NaN
# 165        NaN      NaN                NaN                  NaN
# 166        NaN      NaN                NaN                  NaN
# 197        NaN      NaN                NaN                  NaN
#
#      US_Wealth_Porrest  US_wealth_second  US_wealth_Middle  US_wealth_Fourth  \
# 51                 NaN               NaN               NaN               NaN
# 58                 NaN               NaN               NaN               NaN
# 165                NaN               NaN               NaN               NaN
# 166                NaN               NaN               NaN               NaN
# 197                NaN               NaN               NaN               NaN
#
#      US_wealth_Richest US_Data_Source  US_Time_Period
# 51                 NaN            NaN             NaN
# 58                 NaN            NaN             NaN
# 165                NaN            NaN             NaN
# 166                NaN            NaN             NaN
# 197                NaN            NaN             NaN

# %%
developing_countriesUpSec_without_na = developing_countriesUpSec.dropna()

# %%
developing_countriesUpSec_without_na.isnull().any().any()
# Out:
# False

# %%
developing_countriesUpSec_without_na.shape
# Out:
# (42, 17)

# %%
developing_countriesUpSec_without_na_reset = developing_countriesUpSec_without_na.reset_index(drop=True)

# %%
developing_countriesUpSec_without_na_reset.head()
# Out:
#   ISO3      Country Region  Sub-Region US_Development Region   US_Total  \
# 0  AFG  Afghanistan      SA         SA        Least Developed      58.0
# 1  AGO       Angola     SSA        ESA        Least Developed      29.0
# 2  BGD   Bangladesh      SA         SA        Least Developed      31.0
# 3  BEN        Benin     SSA        WCA        Least Developed      58.0
# 4  BTN       Bhutan      SA         SA        Least Developed      39.0
#
#    Female_US  Male_US  USresidence_Rural  USresidence_Uraban   \
# 0       73.0     43.0               63.0                 45.0
# 1       35.0     21.0               53.0                 19.0
# 2       26.0     37.0               32.0                 30.0
# 3       66.0     50.0               65.0                 50.0
# 4       40.0     39.0               44.0                 27.0
#
#    US_Wealth_Porrest  US_wealth_second  US_wealth_Middle  US_wealth_Fourth  \
# 0               70.0              64.0              64.0              54.0
# 1               58.0              50.0              27.0              17.0
# 2               45.0              35.0              29.0              28.0
# 3               82.0              73.0              61.0              48.0
# 4               55.0              53.0              42.0              27.0
#
#    US_wealth_Richest US_Data_Source  US_Time_Period
# 0               40.0       DHS 2015          2015.0
# 1                9.0    DHS 2015-16          2016.0
# 2               19.0      MICS 2019          2019.0
# 3               36.0    DHS 2017-18          2018.0
# 4               24.0      MICS 2010          2010.0

# %%
developing_countriesUpSec_without_na_reset.to_csv('UperSecondaryCleanedDevelopingCountriesOnly.csv')
